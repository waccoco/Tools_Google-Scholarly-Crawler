# %%
# !pip install scholarly
# !pip install pandas
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %%
import os
import requests
import time
import random
import sqlite3
import csv
from scholarly import scholarly
import pandas as pd

# %%
def create_database(db_name="scholar_data.db"):
    """
    建立 SQLite 資料庫及表格
    """
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS papers (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            title TEXT,
            authors TEXT,
            year TEXT,
            abstract TEXT,
            venue TEXT,
            pdf_link TEXT,
            citations_link TEXT,
            num_citations INTEGER,
            publication_url TEXT
        )
    ''')
    conn.commit()
    return conn

def insert_paper(conn, paper):
    """
    插入單筆資料到資料庫
    """
    cursor = conn.cursor()
    cursor.execute('''
        INSERT INTO papers (title, authors, year, abstract, venue, pdf_link, citations_link, num_citations, publication_url)
        VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
    ''', (
        paper['title'],
        paper['authors'],
        paper['year'],
        paper['abstract'],
        paper['venue'],
        paper['pdf_link'],
        paper['citations_link'],
        paper['num_citations'],
        paper['publication_url']
    ))

def save_to_excel(results, file_name="scholar_results.xlsx"):
    #將結果儲存為 Excel 檔案，並將指定欄位設定為超連結
    df = pd.DataFrame(results)

    # 設定 PDF 連結和文章連結為 Hyperlink
    for col in ['pdf_link', 'publication_url']:
        if col in df.columns:
            df[col] = df[col].apply(lambda x: f'=HYPERLINK("{x}", "{x}")' if pd.notna(x) else x)

    # 將資料寫入 Excel
    with pd.ExcelWriter(file_name, engine='openpyxl') as writer:
        df.to_excel(writer, index=False)



def save_to_csv(results, file_name="scholar_results.csv"):
    """
    將結果存為 CSV 檔案
    """
    keys = ['title', 'authors', 'year', 'abstract', 'venue', 'pdf_link', 'citations_link', 'num_citations', 'publication_url']
    with open(file_name, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.DictWriter(file, fieldnames=keys)
        writer.writeheader()
        writer.writerows(results)
        
# def setup_proxies():
#     """
#     設定代理和重試避免被 Google Scholar 封鎖
#     """
#     proxies = {
#         'http': 'http://your_proxy_address:port',
#         'https': 'http://your_proxy_address:port'
#     }
#     session = requests.Session()
#     retries = Retry(total=5, backoff_factor=1, status_forcelist=[429, 500, 502, 503, 504])
#     session.proxies = proxies
#     session.mount('http://', HTTPAdapter(max_retries=retries))
#     session.mount('https://', HTTPAdapter(max_retries=retries))
#     return session

def search_scholar(keyword, limit=10, conn=None, commit_interval=10, year_low=None, year_high=None, sort_by='relevance'):
    from scholarly import ProxyGenerator

    print(1121)
    # 使用付費代理
    # pg = ProxyGenerator()
    # pg.ScraperAPI('your_scraper_api_key')  # 替換為你的 API 金鑰
    # scholarly.use_proxy(pg)
    
    results = []

    print(1122)
    for _ in range(3):  # 最多重試 3 次
        try:
            search_query = scholarly.search_pubs(
                query=keyword,
                year_low=year_low,
                year_high=year_high,
                sort_by=sort_by
            )

            for i in range(limit):
                print("Catch paper #_"+ str(i))
                # print(search_query)
                time.sleep(random.uniform(5, 10))  # 增加延遲，模擬人類行為
                    
                pub = next(search_query)

                #***************************************************  似乎scholarly.search_pubs都還是沒辦法限制 year_high
                ## 提取資料
                # bib = pub.get('bib', {})
                # pub_year = int(bib.get('pub_year', '0')) if bib.get('pub_year') else None

                # # 手動篩選年份
                # if year_low and pub_year and pub_year < year_low:
                #     continue
                # if year_high and pub_year and pub_year > year_high:
                #     continue
                # #***************************************************

                
                # 提取資料
                bib = pub.get('bib', {})
                result_dict = {
                    'title': bib.get('title', ''),
                    'authors': ", ".join(bib.get('author', [])),
                    'year': bib.get('pub_year', ''),
                    'abstract': bib.get('abstract', ''),
                    'venue': bib.get('venue', ''),
                    'pdf_link': pub.get('eprint_url', None),
                    'citations_link': pub.get('citedby_url', None),
                    'num_citations': pub.get('num_citations', None),
                    'publication_url': pub.get('pub_url', None)
                }

                results.append(result_dict)

                # 插入資料到資料庫
                if conn:
                    insert_paper(conn, result_dict)

                # 每 10 筆提交一次
                if conn and (i + 1) % commit_interval == 0:
                    conn.commit()

            break  # 成功後跳出重試迴圈

        except StopIteration:
            print("搜尋結果已無更多資料。")
            break
        except Exception as e:
            print(f"發生錯誤，重試中... 錯誤訊息: {e}")
            time.sleep(30)  # 等待 30 秒後重試

    # 最後提交資料
    if conn:
        conn.commit()

    return results



def search_scholar_org(keyword, limit=10, conn=None, commit_interval=10, year_low=None, year_high=None, sort_by='relevance'):
    """
    使用 scholar 搜尋指定關鍵字，回傳前 limit 筆結果的資訊，並存入資料庫。
    """
    from scholarly import ProxyGenerator
    
    print(112)
    # Set up a ProxyGenerator object to use free proxies
    # This needs to be done only once per session
    pg = ProxyGenerator()
    pg.FreeProxies()
    scholarly.use_proxy(pg)
    print(113)

    
    search_query = scholarly.search_pubs(
        query=keyword,
        year_low=year_low,
        year_high=year_high,
        sort_by=sort_by
    )
    print(114)

    results = []

    for i in range(limit):
        print(i, limit)
        try:
            # 模擬人類行為：隨機延遲
            time.sleep(random.uniform(3, 10))

            # 取得下一篇文章資訊
            pub = next(search_query)
            
            #print(pub) #方便查看結構

            # 從 `pub` 的結構提取所需資訊
            bib = pub.get('bib', {})
            title = bib.get('title', '')
            authors = ", ".join(bib.get('author', []))  # 將作者列表轉為逗號分隔的字串
            year = bib.get('pub_year', '')
            abstract = bib.get('abstract', '')
            venue = bib.get('venue', '')

            # 提取其他資訊
            url_pdf = pub.get('eprint_url', None)  # PDF 連結
            url_citations = pub.get('citedby_url', None)  # 引用其他文章的連結
            num_citations = pub.get('num_citations', None)  # 引用次數
            pub_url = pub.get('pub_url', None)  # 文章的公開 URL

            result_dict = {
                'title': title,
                'authors': authors,
                'year': year,
                'abstract': abstract,
                'venue': venue,
                'pdf_link': url_pdf,
                'citations_link': url_citations,
                'num_citations': num_citations,
                'publication_url': pub_url
            }
            results.append(result_dict)

            # 插入資料到資料庫
            if conn:
                insert_paper(conn, result_dict)

            # 每 10 筆資料進行一次 commit
            if conn and (i + 1) % commit_interval == 0:
                conn.commit()

        except StopIteration:
            print("搜尋結果已無更多資料。")
            break  # 搜尋結果已無更多資料
        except Exception as e:
            print(f"發生錯誤: {e}")

    # 確保最後的資料被提交
    if conn:
        conn.commit()

    return results

def download_pdf(pdf_url, save_folder='pdf_files_Device', file_prefix='paper'):
    """
    根據 pdf_url 下載 PDF，如果有 pdf_url 而且確實能下載。
    """
    if pdf_url is None:
        return None

    # 建立儲存 PDF 的資料夾
    if not os.path.exists(save_folder):
        os.makedirs(save_folder, exist_ok=True)

    try:
        response = requests.get(pdf_url, timeout=10)
        if response.status_code == 200 and 'application/pdf' in response.headers.get('Content-Type', ''):
            file_name = f"{file_prefix}_{os.path.basename(pdf_url).split('?')[0]}"
            if not file_name.endswith(".pdf"):
                file_name += ".pdf"
            file_path = os.path.join(save_folder, file_name)
            with open(file_path, 'wb') as f:
                f.write(response.content)
            return file_path
        else:
            return None
    except Exception as e:
        print(f"下載失敗: {e}")
        return None

# %%
def main():
    #搜尋條件輸入
    keyword = "machine learning, semiconductor device, deep learning"  # 這裡可以換成你要的關鍵字
    limit = 1500 # 搜尋前 50 筆結果
    year_low = 2015  # 篩選年份下限
    year_high = 2023  # 篩選年份上限
    sort_by = 'date'  # 試著以日期排序

    # 建立資料庫
    conn = create_database()
    print(111)
    # 第一步：搜尋並儲存文獻資訊到資料庫
    results = search_scholar(
        keyword=keyword,
        limit=limit,
        conn=conn,
        commit_interval=10, #每十筆儲存一次，避免中斷爬的都沒存到
        year_low=year_low,
        year_high=year_high,
        sort_by=sort_by
    )
    print(222)

    # 顯示結果
    print(f"共有 {len(results)} 筆文獻資料。")

    # 第二步：儲存結果為 CSV 檔案
    # save_to_csv(results, file_name="scholar_results.csv")
    save_to_excel(results, file_name="scholar_results.xlsx")

    # 第三步：輸出結果至csv or excel並且嚐試下載pdf檔案
    for idx, paper in enumerate(results):
        print(f"\n=== 第 {idx + 1} 筆結果 ===")
        print("標題:", paper['title'])
        print("作者:", paper['authors'])
        print("年份:", paper['year'])
        print("期刊/會議:", paper['venue'])
        print("摘要:", paper['abstract'])
        print("引用次數:", paper['num_citations'])
        print("文章連結:", paper['publication_url'])
        print("PDF 連結:", paper['pdf_link'])
        print("引用文獻連結:", paper['citations_link'])

        # 若存在可用的 PDF 連結，則嘗試下載
        if paper['pdf_link']:
            # pdf_path = download_pdf(paper['pdf_link'], file_prefix=f"paper_{idx+1}")
            pdf_path = download_pdf(paper['pdf_link'], file_prefix=f"{paper['year']}_{paper['title'].replace(' ', '_')}.pdf")

            if pdf_path:
                print(f"PDF 已下載至: {pdf_path}")
            else:
                print("PDF 連結存在，但無法成功下載。")
        else:
            print("查無 PDF 連結或無法下載。")

    # 關閉資料庫連線
    conn.close()

if __name__ == "__main__":
    main()
# Out:
# 111
# 1121
# 1122
# Catch paper #_0
# Catch paper #_1
# Catch paper #_2
# Catch paper #_3
# Catch paper #_4
# Catch paper #_5
# Catch paper #_6
# Catch paper #_7
# Catch paper #_8
# Catch paper #_9
# Catch paper #_10
# Catch paper #_11
# Catch paper #_12
# Catch paper #_13
# Catch paper #_14
# Catch paper #_15
# Catch paper #_16
# Catch paper #_17
# Catch paper #_18
# Catch paper #_19
# Catch paper #_20
# Catch paper #_21
# Catch paper #_22
# Catch paper #_23
# Catch paper #_24
# Catch paper #_25
# Catch paper #_26
# Catch paper #_27
# Catch paper #_28
# Catch paper #_29
# Catch paper #_30
# Catch paper #_31
# Catch paper #_32
# Catch paper #_33
# Catch paper #_34
# Catch paper #_35
# Catch paper #_36
# Catch paper #_37
# Catch paper #_38
# Catch paper #_39
# Catch paper #_40
# Catch paper #_41
# Catch paper #_42
# Catch paper #_43
# Catch paper #_44
# Catch paper #_45
# Catch paper #_46
# Catch paper #_47
# Catch paper #_48
# Catch paper #_49
# Catch paper #_50
# Catch paper #_51
# Catch paper #_52
# Catch paper #_53
# Catch paper #_54
# Catch paper #_55
# Catch paper #_56
# Catch paper #_57
# Catch paper #_58
# Catch paper #_59
# Catch paper #_60
# Catch paper #_61
# Catch paper #_62
# Catch paper #_63
# Catch paper #_64
# Catch paper #_65
# Catch paper #_66
# Catch paper #_67
# Catch paper #_68
# Catch paper #_69
# Catch paper #_70
# Catch paper #_71
# Catch paper #_72
# Catch paper #_73
# Catch paper #_74
# Catch paper #_75
# Catch paper #_76
# Catch paper #_77
# Catch paper #_78
# Catch paper #_79
# Catch paper #_80
# Catch paper #_81
# Catch paper #_82
# Catch paper #_83
# Catch paper #_84
# Catch paper #_85
# Catch paper #_86
# Catch paper #_87
# Catch paper #_88
# Catch paper #_89
# Catch paper #_90
# Catch paper #_91
# Catch paper #_92
# Catch paper #_93
# Catch paper #_94
# Catch paper #_95
# Catch paper #_96
# Catch paper #_97
# Catch paper #_98
# Catch paper #_99
# Catch paper #_100
# Catch paper #_101
# Catch paper #_102
# Catch paper #_103
# Catch paper #_104
# Catch paper #_105
# Catch paper #_106
# Catch paper #_107
# Catch paper #_108
# Catch paper #_109
# Catch paper #_110
# Catch paper #_111
# Catch paper #_112
# Catch paper #_113
# Catch paper #_114
# Catch paper #_115
# Catch paper #_116
# Catch paper #_117
# Catch paper #_118
# 搜尋結果已無更多資料。
# 222
# 共有 118 筆文獻資料。
#
# === 第 1 筆結果 ===
# 標題: Fault diagnosis for ion mill etching machine cooling system based on omni-dimensional dynamic convolution and dynamic spatial pyramid pooling
# 作者: F Wang, J Li, C Deng, R Zhao
# 年份: 2025
# 期刊/會議: Nondestructive Testing and …
# 摘要: 4 days ago -  on machine learning and deep learning techniques to semiconductor  equipment  layer is a common type of neural network layer in deep neural networks [Citation40],
# 引用次數: 0
# 文章連結: https://www.tandfonline.com/doi/abs/10.1080/10589759.2025.2459310
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 2 筆結果 ===
# 標題: A New Deep Reinforcement Learning Run-to-Run Control Algorithm for Mixed-Product Production Mode in Semiconductor Manufacturing
# 作者: SKS Fan, TJ Chen
# 年份: 2025
# 期刊/會議: IEEE Transactions on Automation Science …
# 摘要: 19 days ago -  deep neural networks, thus dubbed “Deep” in its name. By using deep neural  networks mixedproduct production mode, the semiconductor equipment model studied in [17]-
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10843296/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 3 筆結果 ===
# 標題: Sub-bandgap charge harvesting and energy up-conversion in metal halide perovskites: ab initio quantum dynamics
# 作者: B Wang, W Chu, Y Wu, WA Saidi
# 年份: 2025
# 期刊/會議: npj Computational …
# 摘要: 22 days ago -  , nonadiabatic molecular dynamics and machine learning, we advance quantum   and deep. While defect levels fluctuate more in MHPs than traditional semiconductors,
# 引用次數: 1
# 文章連結: https://www.nature.com/articles/s41524-024-01467-4
# PDF 連結: https://www.nature.com/articles/s41524-024-01467-4
# 引用文獻連結: /scholar?cites=7890368307077107779&as_sdt=5,33&sciodt=0,33&hl=en
# PDF 連結存在，但無法成功下載。
#
# === 第 4 筆結果 ===
# 標題: An Improved YOLOv7-tiny-Based Algorithm for Wafer Surface Defect Detection
# 作者: M Li, X Wang, H Zhang, X Hu
# 年份: 2025
# 期刊/會議: IEEE Access
# 摘要: 24 days ago -  the limitations of existing machine learning methods, this paper  and intelligence,  semiconductor technology plays an  When deep neural networks are applied to real-time
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10836686/
# PDF 連結: https://ieeexplore.ieee.org/iel8/6287639/6514899/10836686.pdf
# 引用文獻連結: None
# PDF 連結存在，但無法成功下載。
#
# === 第 5 筆結果 ===
# 標題: Large-scale integrated photonic device platform for energy-efficient AI/ML accelerators
# 作者: B Tossoun, X Xiao, S Cheung, Y Yuan
# 年份: 2025
# 期刊/會議: IEEE Journal of …
# 摘要: 25 days ago -  for machine learning (ML). More recently, the heterogeneous integration of  III-V compound semiconductors has opened the door to integrating lasers and semiconductor
# 引用次數: 1
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10835188/
# PDF 連結: None
# 引用文獻連結: /scholar?cites=10435521242069634167&as_sdt=5,33&sciodt=0,33&hl=en
# 查無 PDF 連結或無法下載。
#
# === 第 6 筆結果 ===
# 標題: Machine learning driven measurement of high-aspect-ratio nanostructures using Mueller matrix spectroscopic ellipsometry
# 作者: S Mudide, N Keller, G Andrew Antonelli
# 年份: 2025
# 期刊/會議: Journal of Vacuum …
# 摘要: 33 days ago -  Accurate fabrication of high-aspect ratio (HAR) structures in applications  from semiconductor devices to x-ray observatories is essential for their optimal performance
# 引用次數: 0
# 文章連結: https://pubs.aip.org/avs/jvb/article/43/1/012801/3329206
# PDF 連結: https://pubs.aip.org/avs/jvb/article/43/1/012801/3329206
# 引用文獻連結: None
# PDF 連結存在，但無法成功下載。
#
# === 第 7 筆結果 ===
# 標題: OPTIMIZED LITHOGRAPHIC HOTSPOT DETECTION WITH MULTI-TASK DEEP LEARNING
# 作者: A Mehta, N Sharma, R Kumar
# 年份: 2024
# 期刊/會議: NA
# 摘要: 38 days ago -  semiconductor manufacturing is undergoing a transformation, driven by  advancements in machine learning and deep learning  performance of semiconductor devices. By
# 引用次數: 0
# 文章連結: http://www.upubscience.com/upload/20241226165234.pdf
# PDF 連結: http://www.upubscience.com/upload/20241226165234.pdf
# 引用文獻連結: None
# PDF 已下載至: pdf_files_Device\2024_OPTIMIZED_LITHOGRAPHIC_HOTSPOT_DETECTION_WITH_MULTI-TASK_DEEP_LEARNING.pdf_20241226165234.pdf
#
# === 第 8 筆結果 ===
# 標題: A DEEP LEARNING APPROACH TO LITHOGRAPHIC HOTSPOT DETECTION IN SEMICONDUCTOR MANUFACTURING
# 作者: L Zhang, K Wong
# 年份: 2024
# 期刊/會議: NA
# 摘要: 38 days ago -  machine learning techniques, specifically convolutional  By employing deep  learning, we aim to improve detection  yields and better-performing semiconductor devices.
# 引用次數: 0
# 文章連結: http://upubscience.com/upload/20241226141131.pdf
# PDF 連結: http://upubscience.com/upload/20241226141131.pdf
# 引用文獻連結: None
# PDF 已下載至: pdf_files_Device\2024_A_DEEP_LEARNING_APPROACH_TO_LITHOGRAPHIC_HOTSPOT_DETECTION_IN_SEMICONDUCTOR_MANUFACTURING.pdf_20241226141131.pdf
#
# === 第 9 筆結果 ===
# 標題: Single-Event Burnout in Semiconductor Devices: Efficient Classification of Ion Species
# 作者: JT Santos, RAC Bianchi, MA Guazzelli
# 年份: 2024
# 期刊/會議: Journal of Integrated …
# 摘要: 41 days ago -  Like all deep learning architectures, they require a vast amount of  Machine  Learning (ML) techniques to analyze the effects of ionizing radiation on electronic devices
# 引用次數: 0
# 文章連結: https://jics.org.br/ojs/index.php/JICS/article/view/933
# PDF 連結: https://jics.org.br/ojs/index.php/JICS/article/download/933/521
# 引用文獻連結: None
# PDF 已下載至: pdf_files_Device\2024_Single-Event_Burnout_in_Semiconductor_Devices:_Efficient_Classification_of_Ion_Species.pdf_521.pdf
#
# === 第 10 筆結果 ===
# 標題: Security, Utility, Performance, and Adoption
# 作者: AB Popa, ER Rughinis
# 年份: NA
# 期刊/會議: NA
# 摘要: 47 days ago -  The list includes areas such as semiconductors and material science, space   in artificial intelligence (machine learning, deep learning, reinforcement learning, generative AI
# 引用次數: 0
# 文章連結: https://docs.upb.ro/wp-content/uploads/2024/12/popa_alin_rezumat.pdf
# PDF 連結: https://docs.upb.ro/wp-content/uploads/2024/12/popa_alin_rezumat.pdf
# 引用文獻連結: None
# PDF 已下載至: pdf_files_Device\NA_Security,_Utility,_Performance,_and_Adoption.pdf_popa_alin_rezumat.pdf
#
# === 第 11 筆結果 ===
# 標題: Investigating Wafer Surface Defect Detection: An Analysis of Approaches and Developments
# 作者: PD Devi, G Kavya
# 年份: 2024
# 期刊/會議: … on IoT Based Control Networks and …
# 摘要: 48 days ago -  to maintaining product quality in semiconductor device manufacturing. Silicon  wafer  accuracy, deep neural networks perform better than conventional machine learning
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10823128/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 12 筆結果 ===
# 標題: Data Driven Compact Modeling of a Reconfigurable FET
# 作者: MJ Reuter
# 年份: NA
# 期刊/會議: NA
# 摘要: 48 days ago -  of emerging semiconductor devices by proposing two approaches to obtain  characteristic device  Further, this work explores machine learning-based regression methods.
# 引用次數: 0
# 文章連結: https://tuprints.ulb.tu-darmstadt.de/28629/
# PDF 連結: https://tuprints.ulb.tu-darmstadt.de/28629/1/diss_maxr_rfet_tuprints_final_submission.pdf
# 引用文獻連結: None
# PDF 已下載至: pdf_files_Device\NA_Data_Driven_Compact_Modeling_of_a_Reconfigurable_FET.pdf_diss_maxr_rfet_tuprints_final_submission.pdf
#
# === 第 13 筆結果 ===
# 標題: Generating TCN Models From Parallel Devs Models: Semiconductor Manufacturing Systems
# 作者: VK Pendyala, HS Sarjoughian
# 年份: 2024
# 期刊/會議: 2024 Winter Simulation …
# 摘要: 50 days ago -  Synthetic manufacturing datasets for machine learning  the development of  machine learning models and illuminates  , the integration of machine learning into large-scale
# 引用次數: 1
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10838759/
# PDF 連結: None
# 引用文獻連結: /scholar?cites=10643143867022364847&as_sdt=5,33&sciodt=0,33&hl=en
# 查無 PDF 連結或無法下載。
#
# === 第 14 筆結果 ===
# 標題: Yield Improvement Using Deep Reinforcement Learning for Dispatch Rule Tuning
# 作者: D Norman, P Dawadi
# 年份: 2024
# 期刊/會議: 2024 Winter Simulation …
# 摘要: 50 days ago -  yield in semiconductor manufacturing using reinforcement  deep reinforcement  learning and graph neural networks is the subject of this paper. Graph neural networks (
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10838741/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 15 筆結果 ===
# 標題: Enhancement of Vendor-Managed Inventory Planning Through Deep Reinforcement Learning
# 作者: M Ratusny, JH Kim, H Sekiya
# 年份: 2024
# 期刊/會議: 2024 Winter …
# 摘要: 51 days ago -  “A deep reinforcement learning approach for optimal replenishment policy  in a vendor managed inventory setting for semiconductors”. In 2020 Winter Simulation
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10838627/
# PDF 連結: https://www.researchgate.net/profile/Hans-Ehm/publication/386905410_ENHANCEMENT_OF_VENDOR-MANAGED_INVENTORY_PLANNING_THROUGH_DEEP_REINFORCEMENT_LEARNING/links/675ad28e72215358fe2d5fc2/ENHANCEMENT-OF-VENDOR-MANAGED-INVENTORY-PLANNING-THROUGH-DEEP-REINFORCEMENT-LEARNING.pdf
# 引用文獻連結: None
# PDF 連結存在，但無法成功下載。
#
# === 第 16 筆結果 ===
# 標題: Adaptive machine learning for manufactured IC image analysis
# 作者: YY Tee
# 年份: 2024
# 期刊/會議: NA
# 摘要: 52 days ago -  and necessity of semiconductor devices worldwide. Circuit  Deep learning  techniques have been demonstrated to  In this thesis, adaptive machine learning techniques
# 引用次數: 0
# 文章連結: https://dr.ntu.edu.sg/handle/10356/181526
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 17 筆結果 ===
# 標題: Artificial Intelligence-assisted Microfluidic Bio-imaging—from Sensors to Applications: A Review
# 作者: J Chen, L Fu, R Xiang, S Luo, X Huang
# 年份: 2024
# 期刊/會議: IEEE Sensors …
# 摘要: 60 days ago -  (CCDs) and complementary metal-oxide-semiconductor  various machine  learning and deep learning algorithms  , allowing a deep neural network to obtain information
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10780947/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 18 筆結果 ===
# 標題: Machine learning-assisted investigation on the thermal transport of β-Ga2O3 with vacancy
# 作者: S Dong, G Zhang, G Zhang, X Lan, X Wang
# 年份: 2024
# 期刊/會議: The Journal of Chemical …
# 摘要: 61 days ago -  devices, making it one of the leading candidates for next-generation semiconductor   O 3 improve its suitability for high-voltage device applications. However, the thermal
# 引用次數: 0
# 文章連結: https://pubs.aip.org/aip/jcp/article/161/21/214705/3323348
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 19 筆結果 ===
# 標題: Enhancing Semiconductor X-RAY Images: A Framework Combining Denoising and Super-Resolution Modules With a Novel Dataset
# 作者: JH Shim, MW Kim, TG Lim, BS Min
# 年份: 2024
# 期刊/會議: 2024 Asia Pacific …
# 摘要: 62 days ago -  and machine inspectors. Therefore, in this paper, we present a new semiconductor  image dataset and a deep-learning  Since most semiconductor images are intended for
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10849281/
# PDF 連結: http://www.apsipa2024.org/files/papers/95.pdf
# 引用文獻連結: None
# PDF 已下載至: pdf_files_Device\2024_Enhancing_Semiconductor_X-RAY_Images:_A_Framework_Combining_Denoising_and_Super-Resolution_Modules_With_a_Novel_Dataset.pdf_95.pdf
#
# === 第 20 筆結果 ===
# 標題: Meta-Learning Based Indoor Localization: A Hierarchical Framework
# 作者: H Yu, C She, Y Hu, Z Geng
# 年份: 2024
# 期刊/會議: IEEE Transactions on …
# 摘要: 68 days ago -  devices (MD). To address the issues, we first propose a hierarchical framework  that divides the deep neural network ( of artificial intelligence (AI)/machine learning (ML),
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10767394/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 21 筆結果 ===
# 標題: The Usage of Electroimpedance Tomography along with Artificial Intelligence in Application Development in the field of Medicine
# 作者: M Mušikić
# 年份: 2024
# 期刊/會議: 2024 32nd Telecommunications Forum (TELFOR)
# 摘要: 69 days ago -  Abstract - This study investigates the integration of Electroimpedance  Tomography (EIT) with Machine Learning (ML) and Deep Learning (DL) for enhanced object
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10819142/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 22 筆結果 ===
# 標題: An Ensemble Deep CNN Approach for Power Quality Disturbance Classification: A Technological Route Towards Smart Cities Using Image-Based Transfer
# 作者: MAA Baig, NI Ratyal, A Amin, U Jamil, S Liaquat
# 年份: 2024
# 期刊/會議: Future Internet
# 摘要: 73 days ago -  semiconductor devices  machine learning classifiers or signal processing  methods. However, recent advancements have introduced Deep Convolution Neural Networks (
# 引用次數: 0
# 文章連結: https://www.mdpi.com/1999-5903/16/12/436
# PDF 連結: https://www.mdpi.com/1999-5903/16/12/436
# 引用文獻連結: None
# PDF 連結存在，但無法成功下載。
#
# === 第 23 筆結果 ===
# 標題: Fault Diagnosis of Industrial Robots using CNN and Vibration Data
# 作者: MJ Kim, KM Ku, S Islam, MJ Chung
# 年份: 2024
# 期刊/會議: … of the Semiconductor …
# 摘要: 75 days ago -  over tasks previously requiring specialized equipment or skilled human  operators.  to build a learning model, and in this study, the CNN (Convolutional Neural Network)
# 引用次數: 0
# 文章連結: https://koreascience.kr/article/JAKO202432455968903.page
# PDF 連結: https://koreascience.kr/article/JAKO202432455968903.pdf
# 引用文獻連結: None
# PDF 已下載至: pdf_files_Device\2024_Fault_Diagnosis_of_Industrial_Robots_using_CNN_and_Vibration_Data.pdf_JAKO202432455968903.pdf
#
# === 第 24 筆結果 ===
# 標題: Comparative Analysis and Implementation of Energy-Quality Scalable Multiply-Accumulate Architectures for TinyML Applications
# 作者: KDC Pelayo, AB Alvarez, AN Chua
# 年份: 2024
# 期刊/會議: 2024 31st IEEE …
# 摘要: 77 days ago -  Abstract—Recent trends in machine learning algorithms  as ultra-low power  devices. This shift presents new  ] that real-world deep neural network (DNN) models are
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10848625/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 25 筆結果 ===
# 標題: Overview of Silicon Carbide Wafer Defect Types and Inspection Techniques
# 作者: YC Liu, WJ Chen, X Qi, Y Shen, L Gu
# 年份: 2024
# 期刊/會議: … Semiconductors  …
# 摘要: 77 days ago -  In addition, this study explores the potential of machine learning techniques  in defect detection to promote the automation and intelligent development of defect detection
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10835376/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 26 筆結果 ===
# 標題: Reconstruction-based neural networks for anomaly detection in microscopic integrated circuit images
# 作者: NN Vinh
# 年份: 2024
# 期刊/會議: NA
# 摘要: 79 days ago -  These elements are etched onto a small piece of semiconductor material,  a  machine learning anomaly detection method using the Reconstruction-Based Neural Network
# 引用次數: 0
# 文章連結: https://epub.vgu.edu.vn/handle/dlibvgu/1878
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 27 筆結果 ===
# 標題: Interpretable Surrogate Learning for Electronic Material Generation
# 作者: Z Wang, S Liu, K Tao, A Chen, H Duan, Y Han, F You
# 年份: 2024
# 期刊/會議: ACS …
# 摘要: 93 days ago -  flexible AI models such as deep neural networks (DNNs) are often  semiconductor  with a wide E g , holding substantial promise in the field of DUV optoelectronic devices (
# 引用次數: 0
# 文章連結: https://pubs.acs.org/doi/abs/10.1021/acsnano.4c12166
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 28 筆結果 ===
# 標題: Anomaly Detection System for Semiconductor Deposition Process using Transformer
# 作者: MH Ha, S Arshad, MS Chae, SC Yun
# 年份: 2024
# 期刊/會議: … and Systems (ICCAS …
# 摘要: 97 days ago -  sensors to semiconductor equipment to receive realtime  in semiconductor  manufacturing equipment includes a  fields outside of semiconductor equipment. Studies in
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10773356/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 29 筆結果 ===
# 標題: Deep Learning Assisted Hybrid Metrology of Nanosheet Transistors for Fast Film Characterization
# 作者: T Cai, Y Li, D Schmidt, R Jaramillo
# 年份: 2024
# 期刊/會議: Materials Research Society …
# 摘要: 100 days ago -  machine learning methods to improve the accuracy and speed of data analysis  for thin film characterization. We demonstrate this idea by using a deep learning  device
# 引用次數: 0
# 文章連結: https://research.ibm.com/publications/deep-learning-assisted-hybrid-metrology-of-nanosheet-transistors-for-fast-film-characterization
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 30 筆結果 ===
# 標題: A Data Driven Correction Algorithm for Inverse Problems with Application to Spectral Reconstruction
# 作者: J Laubmann, S Saloman, J Wissing
# 年份: 2024
# 期刊/會議: 2024 IEEE …
# 摘要: 106 days ago -  In [19] a deep neural network was used for the reconstruction task. Deep neural  networks  correction approach outperforms both classic and machine learning approaches.
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10785213/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 31 筆結果 ===
# 標題: High Dynamic Range Object Detection System with Image Fusion Network Using High-Illumination Specialized Binary Image
# 作者: HU Byeon, TH Eom, HJ Kim
# 年份: 2024
# 期刊/會議: 2024 IEEE SENSORS
# 摘要: 106 days ago -  This research highlights the effectiveness of machine-friendly  of deep  learning has significantly accelerated the growth of related applications, particularly in machine
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10784771/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 32 筆結果 ===
# 標題: Early Screening of Lung Cancer Through Multi-Modal Gas Sensors-Based Breath Analysis Sensor System and Machine Learning
# 作者: DS Lee
# 年份: 2024
# 期刊/會議: 2024 IEEE SENSORS
# 摘要: 106 days ago -  gas sensor array and deep learning algorithm. The breath analysis system  was designed to detect multiple VOCs in exhaled breath using ten semiconductor metal oxide,
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10784854/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 33 筆結果 ===
# 標題: Multi-color long-wave infrared perfect absorber based on a heavily doped semiconductor that is inverse-designed via machine learning
# 作者: Y Feng, S Yue, R Wang, Y Hou, S Cai, Z Wang
# 年份: 2024
# 期刊/會議: Optics …
# 摘要: 114 days ago -  in a conventional MIM MPA with a heavily doped semiconductor (n ++ ), whose  growth  a deep neural network (DNN) to associate the spectral response of the device with
# 引用次數: 0
# 文章連結: https://opg.optica.org/abstract.cfm?uri=oe-32-22-39053
# PDF 連結: https://opg.optica.org/viewmedia.cfm?uri=oe-32-22-39053&seq=0&html=true
# 引用文獻連結: None
# PDF 連結存在，但無法成功下載。
#
# === 第 34 筆結果 ===
# 標題: A Deep Reinforcement Learning Approach to Optimize Closing Down a Single-Arm Cluster Tool
# 作者: WX Liang, QH Zhu, ZR Li, JT Zhou
# 年份: 2024
# 期刊/會議: 2024 IEEE International …
# 摘要: 120 days ago -  Deep reinforcement learning (DRL), capable of adapting  [4], integrating deep  neural networks with Qlearning has  fabrication processes in semiconductor manufacturing.
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10831049/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 35 筆結果 ===
# 標題: Motivating automated multimodal failure analysis for heterogeneously integrated devices
# 作者: P Craig, N Varshney, A Roy, C Woychik
# 年份: 2024
# 期刊/會議: Developments in X …
# 摘要: 122 days ago - The semiconductor industry’s advancements in advanced packaging and  heterogeneous integration have outpaced traditional failure analysis and quality assurance
# 引用次數: 1
# 文章連結: https://www.spiedigitallibrary.org/conference-proceedings-of-spie/13152/1315228/Motivating-automated-multimodal-failure-analysis-for-heterogeneously-integrated-devices/10.1117/12.3028177.short
# PDF 連結: https://www.researchgate.net/profile/Nitin-Varshney-4/publication/384633563_Motivating_automated_multimodal_failure_analysis_for_heterogeneously_integrated_devices/links/670804d668e0f20a610877ea/Motivating-automated-multimodal-failure-analysis-for-heterogeneously-integrated-devices.pdf
# 引用文獻連結: /scholar?cites=1439445884027462013&as_sdt=5,33&sciodt=0,33&hl=en
# PDF 連結存在，但無法成功下載。
#
# === 第 36 筆結果 ===
# 標題: Machine-learning-assisted optical authentication of chip tampering
# 作者: B Wilson, Y Chen, DK Singh, R Ojha
# 年份: 2024
# 期刊/會議: … and Devices to …
# 摘要: 122 days ago -  Several techniques to authenticate semiconductors have been  for semiconductor  device packaging that is resilient to adversarial tampering. Our innovative deep-learning
# 引用次數: 0
# 文章連結: https://www.spiedigitallibrary.org/conference-proceedings-of-spie/PC13113/3027858/Machine-learning-assisted-optical-authentication-of-chip-tampering/10.1117/12.3027858.short
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 37 筆結果 ===
# 標題: Micromotors for environmental remediation and energy generation
# 作者: RF Campos, K Villa
# 年份: 2024
# 期刊/會議: … Machines, Devices, and Applications VII
# 摘要: 126 days ago -  Owing to the photocatalytic nature of semiconductor-based micromotors, these  devices  A deep-learning-based tracking system enables precise micromotor monitoring.
# 引用次數: 0
# 文章連結: https://www.spiedigitallibrary.org/conference-proceedings-of-spie/PC13126/PC1312601/Micromotors-for-environmental-remediation-and-energy-generation/10.1117/12.3028075.short
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 38 筆結果 ===
# 標題: Vibration Based Real Time Fault Diagnosis System Using Deep AutoEncoder
# 作者: 이원섭
# 年份: 2024
# 期刊/會議: NA
# 摘要: 128 days ago -  machine learning are being actively developed. In this study, accelerometers  were attached to the system semiconductor  equipment is picking semiconductor devices, 8
# 引用次數: 0
# 文章連結: https://s-space.snu.ac.kr/handle/10371/210444
# PDF 連結: https://s-space.snu.ac.kr/bitstream/10371/210444/1/000000180591.pdf
# 引用文獻連結: None
# PDF 已下載至: pdf_files_Device\2024_Vibration_Based_Real_Time_Fault_Diagnosis_System_Using_Deep_AutoEncoder.pdf_000000180591.pdf
#
# === 第 39 筆結果 ===
# 標題: Integrating spectral photon counting CT and deep learning for metal artefact reduction
# 作者: OS Khan, B Tariq, N Francis
# 年份: 2024
# 期刊/會議: … Semiconductor …
# 摘要: 129 days ago -  This study introduces a novel machine learning approach called residual  dense U-Net (RDU-Net) for reducing metal artefacts in spectral photon-counting CT (SPCCT)
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10657929/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 40 筆結果 ===
# 標題: Spin qubits in semiconductor devices: automation of measurement, optimisation, and control
# 作者: SB Orbell
# 年份: 2024
# 期刊/會議: NA
# 摘要: 131 days ago -  devices based on deep reinforcement learning and convolutional neural  networks63.  stage, and fed into a deep neural network which controls the DRL decision agent.
# 引用次數: 0
# 文章連結: https://ora.ox.ac.uk/objects/uuid:ae8ea763-6ae1-4ec9-b636-167731469e7b
# PDF 連結: https://ora.ox.ac.uk/objects/uuid:ae8ea763-6ae1-4ec9-b636-167731469e7b/files/d6108vb98v
# 引用文獻連結: None
# PDF 已下載至: pdf_files_Device\2024_Spin_qubits_in_semiconductor_devices:_automation_of_measurement,_optimisation,_and_control.pdf_d6108vb98v.pdf
#
# === 第 41 筆結果 ===
# 標題: Memristive Synapses as Building Blocks of Neuromorphic Artificial Intelligence (AI) Hardware
# 作者: F Gül
# 年份: 2024
# 期刊/會議: 2024 8th International Artificial Intelligence and Data …
# 摘要: 135 days ago -  the use of machine learning and deep learning, yet  components in AI hardware  for deep neural networks (DNNs).  In recent years, Nano-scale semiconductor devices that
# 引用次數: 1
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10711094/
# PDF 連結: None
# 引用文獻連結: /scholar?cites=14175911525860415823&as_sdt=5,33&sciodt=0,33&hl=en
# 查無 PDF 連結或無法下載。
#
# === 第 42 筆結果 ===
# 標題: Hardware-Software Co-optimised Fast and Accurate Deep Reconfigurable Spiking Inference Accelerator Architecture Design Methodology
# 作者: A Nimbekar, P Katti, C Li, BM Al-Hashimi
# 年份: 2024
# 期刊/會議: 2024 IEEE 37th …
# 摘要: 140 days ago -  Neural Networks (SNNs) have emerged as a promising approach to improve  the energy efficiency of machine learning  port software-trained deep neural networks (DNN)
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10737858/
# PDF 連結: https://arxiv.org/pdf/2410.16298
# 引用文獻連結: None
# PDF 已下載至: pdf_files_Device\2024_Hardware-Software_Co-optimised_Fast_and_Accurate_Deep_Reconfigurable_Spiking_Inference_Accelerator_Architecture_Design_Methodology.pdf_2410.16298.pdf
#
# === 第 43 筆結果 ===
# 標題: Enhanced Defect Detection Using ResNet-Based Neural Networks After Wafer Bonding
# 作者: V Dubey, F Stoll, A Kaladan, M Mishra
# 年份: 2024
# 期刊/會議: 2024 IEEE 10th …
# 摘要: 145 days ago -  The deep neural network is evaluated on data collected  for the semiconductor  industry. Additionally, we plan to  : Evaluation of the machine learning classifier in wafer
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10712032/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 44 筆結果 ===
# 標題: Advanced Automatic Defect Detection of Semiconductor Chips: Overcoming Complexity and Diversity with Addnet
# 作者: YD Wong, A Gu, X Shi
# 年份: NA
# 期刊/會議: NA
# 摘要: 153 days ago -  insight into the predicted results, we compared the detection outcomes of  semiconductor defect samples, as illustrated in Figure 5. This figure displays the original data,
# 引用次數: 0
# 文章連結: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=4944502
# PDF 連結: https://papers.ssrn.com/sol3/Delivery.cfm?abstractid=4944502
# 引用文獻連結: None
# PDF 連結存在，但無法成功下載。
#
# === 第 45 筆結果 ===
# 標題: VLSI Physical Design Optimization Using Deep Reinforcement Learning
# 作者: 이승윤
# 年份: 2024
# 期刊/會議: NA
# 摘要: 154 days ago -  nets using reinforcement learning and transfer learning in  the effective application  of reinforcement learning, this  time, cost, and manpower in the semiconductor industry.
# 引用次數: 0
# 文章連結: https://poasis.postech.ac.kr/handle/2014.oak/124054
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 46 筆結果 ===
# 標題: A NEW CHANNEL ESTIMATION FRAMEWORK FOR 6G INTELLIGENT REFLECTING SURFACE-ENABLED MIMO
# 作者: N BEGUM, DRM AMER, DROA LATIF
# 年份: 2024
# 期刊/會議: Journal of Theoretical …
# 摘要: 156 days ago -  This hybrid precoding system utilizes machine learning techniques to optimize  energy efficiency. It incorporates a small number of affordable and energy-efficient switches
# 引用次數: 0
# 文章連結: http://www.jatit.org/volumes/Vol102No16/1Vol102No16.pdf
# PDF 連結: http://www.jatit.org/volumes/Vol102No16/1Vol102No16.pdf
# 引用文獻連結: None
# 下載失敗: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# PDF 連結存在，但無法成功下載。
#
# === 第 47 筆結果 ===
# 標題: Recent progress on artificial intelligence-enhanced multimodal sensors integrated devices and systems
# 作者: H Wang, M Zhou, X Jia, H Wei, Z Hu, W Li
# 年份: 2025
# 期刊/會議: … of Semiconductors
# 摘要: 158 days ago -  Through a comparative study of the dual/tri-modal sensors with and without  using AI technologies (especially machine learning and deep learning), AI-enhanced
# 引用次數: 1
# 文章連結: https://iopscience.iop.org/article/10.1088/1674-4926/24090041/meta
# PDF 連結: https://www.jos.ac.cn/article/doi/10.1088/1674-4926/24090041
# 引用文獻連結: /scholar?cites=10129844875512462437&as_sdt=5,33&sciodt=0,33&hl=en
# PDF 連結存在，但無法成功下載。
#
# === 第 48 筆結果 ===
# 標題: Integration Artificial Intelligence with Conventional X-Ray Inspection for Improved Solder Void Detection in SSDC SiC Modules
# 作者: MHM Sa'at, MH Jamaluddin
# 年份: 2024
# 期刊/會議: … Artificial Intelligence …
# 摘要: 161 days ago -  This platform features advanced cooling and semiconductor technologies  to ensure high performance and reliability. However, one of the critical challenges in
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10730272/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 49 筆結果 ===
# 標題: Advanced Techniques in Semiconductor Defect Detection and Classification: Overview of Current Technologies and Future Trends in AI/ML Integration
# 作者: Y Zheng, KWA Chee
# 年份: 2024
# 期刊/會議: 2024 World Rehabilitation Robot …
# 摘要: 164 days ago -  As semiconductor devices shrink and become more  systems, artificial intelligence  (AI), and machine learning (ML). It  have explored innovative deep neural network-based
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10696150/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 50 筆結果 ===
# 標題: SemiH: DFT Hamiltonian neural network training with semi-supervised learning
# 作者: Y Cho, G Choi, G Ham, M Shin
# 年份: 2024
# 期刊/會議: Machine Learning …
# 摘要: 165 days ago -  as materials science and semiconductor devices. However,  often excel through  supervised learning, relying on  techniques tailored for deep neural networks have been
# 引用次數: 0
# 文章連結: https://iopscience.iop.org/article/10.1088/2632-2153/ad7227/meta
# PDF 連結: https://iopscience.iop.org/article/10.1088/2632-2153/ad7227
# 引用文獻連結: None
# PDF 連結存在，但無法成功下載。
#
# === 第 51 筆結果 ===
# 標題: Device Modeling Based on Cost-Sensitive Densely Connected Deep Neural Networks
# 作者: X Tang, Z Li, L Zeng, H Zhou
# 年份: 2024
# 期刊/會議: … of the Electron Devices …
# 摘要: 166 days ago -  proposes a machine learning-based device modeling  performance than  traditional deep neural networks (DNN) with  and modeling semiconductor devices to predict and
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10643157/
# PDF 連結: https://ieeexplore.ieee.org/iel8/6245494/6423298/10643157.pdf
# 引用文獻連結: None
# PDF 連結存在，但無法成功下載。
#
# === 第 52 筆結果 ===
# 標題: YOLOv4-Based Semiconductor Wafer Notch Detection Using Deep Learning and Image Enhancement Algorithms
# 作者: H Wang, HJ Sim, JJ Hwang, SJ Kwak
# 年份: 2024
# 期刊/會議: International Journal of …
# 摘要: 171 days ago -  deeper than intended because of the channeling effect, compromising the  device  Utilizing a camera-based machine learning system, the system identifies the wafer
# 引用次數: 0
# 文章連結: https://link.springer.com/article/10.1007/s12541-024-01092-7
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 53 筆結果 ===
# 標題: End-to-End Automation in STEM Imaging and Spectroscopy: Revolutionising the Analysis of Quantum Materials and Beyond
# 作者: M Botifoll Moral
# 年份: 2024
# 期刊/會議: NA
# 摘要: 174 days ago -  science, particularly in semiconductor-based devices, requires higher precision  and  focusing on Machine Learning/Deep Learning (ML/DL) and Artificial Intelligence (AI)
# 引用次數: 0
# 文章連結: https://ddd.uab.cat/record/299815
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 54 筆結果 ===
# 標題: A 5T-SRAM Based Computing-in-Memory Macro Featuring Partial Sum Boosting and Analog Non-Uniform Quantization
# 作者: G Xin, F Tan, J Li, J Chen, WH Yu, KF Un
# 年份: 2024
# 期刊/會議: 2024 IEEE 67th …
# 摘要: 176 days ago -  been widely used in various machine learning (ML) applications, which  parallelly  With the rapid development of ML, deep neural networks (DNN) have been widely
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10658831/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 55 筆結果 ===
# 標題: Knowledge Transfer. From Electronic Design Automation to Advanced Process Manufacturing
# 作者: JA Torres, M Tao, A Doinychko
# 年份: 2024
# 期刊/會議: 2024 IEEE 67th …
# 摘要: 176 days ago -  for the design of semiconductor devices can be applied to the manufacturing  processes necessary to build such devices. We will discuss: Why machine learning is a key
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10658922/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 56 筆結果 ===
# 標題: Algorithm prediction of single particle irradiation effect based on novel TFETs
# 作者: C Chong, H Liu, S Wang, Z Wang
# 年份: 2024
# 期刊/會議: Nanotechnology
# 摘要: 177 days ago -  deep learning algorithm model not only enables researchers who are not familiar  with semiconductor devices  research on machine learning, deep learning has gradually
# 引用次數: 0
# 文章連結: https://iopscience.iop.org/article/10.1088/1361-6528/ad6d73/meta
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 57 筆結果 ===
# 標題: MD ABUL HASNATH
# 作者: CO by Implementing
# 年份: NA
# 期刊/會議: NA
# 摘要: 178 days ago -  Machine Learning/Deep learning models were incorporated  intelligence/Machine  Learning. This has great potential to generate huge business value in the semiconductor
# 引用次數: 0
# 文章連結: https://core.ac.uk/download/pdf/603342626.pdf
# PDF 連結: https://core.ac.uk/download/pdf/603342626.pdf
# 引用文獻連結: None
# PDF 已下載至: pdf_files_Device\NA_MD_ABUL_HASNATH.pdf_603342626.pdf
#
# === 第 58 筆結果 ===
# 標題: Optimization of Semiconductor Chip Design Using Artificial Intelligence
# 作者: C Song, B Wu, G Zhao
# 年份: 2024
# 期刊/會議: Journal of Industrial Engineering and …
# 摘要: 185 days ago -  semiconductor chip design, including machine learning, deep learning, and  reinforcement learning.  and future directions in integrating AI with semiconductor chip design.
# 引用次數: 18
# 文章連結: https://www.suaspress.org/ojs/index.php/JIEAS/article/view/v2n4a12
# PDF 連結: None
# 引用文獻連結: /scholar?cites=2723586205260067935&as_sdt=5,33&sciodt=0,33&hl=en
# 查無 PDF 連結或無法下載。
#
# === 第 59 筆結果 ===
# 標題: An ultra-fast and precise automatic design framework for predicting and constructing high-performance shallow-trench-isolation LDMOS devices
# 作者: C Xu, H Tang, Y Zhu, Y Cheng, X Jin, D Gao
# 年份: 2025
# 期刊/會議: Journal of …
# 摘要: 186 days ago -  (BO) algorithm, and deep neural network (DNN) model is  than that for other  machine learning (ML) algorithms. On  symposium on power semiconductor devices and ICs (
# 引用次數: 0
# 文章連結: https://link.springer.com/article/10.1007/s10825-024-02244-8
# PDF 連結: https://www.researchsquare.com/article/rs-4696885/latest.pdf
# 引用文獻連結: None
# PDF 已下載至: pdf_files_Device\2025_An_ultra-fast_and_precise_automatic_design_framework_for_predicting_and_constructing_high-performance_shallow-trench-isolation_LDMOS_devices.pdf_latest.pdf
#
# === 第 60 筆結果 ===
# 標題: Enhanced Security Measures for Government and Military: ANN and Decision Tree Approach to Counter VPN Malicious Transmission
# 作者: A Kumari, D Gupta, M Uppal
# 年份: 2024
# 期刊/會議: … Intelligence and Computing (AIC …
# 摘要: 191 days ago -  Machine learning techniques can be used to improve  Anomaly detection  based on machine learning is a totally  , both machine learning and deep learning have been
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10730911/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 61 筆結果 ===
# 標題: Enhanced Semiconductor Wafer Defect Classification with CNN and SVM
# 作者: V Yadav, D Banerjee, D Upadhyay
# 年份: 2024
# 期刊/會議: 2024 Asia Pacific …
# 摘要: 192 days ago -  on semiconductor wafers, this work presents a vision-based machine learning  approach.  In this paper, a unique ADC method utilizing Deep Neural Networks (DNNs) is
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10673497/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 62 筆結果 ===
# 標題: Contrast Optimization Aided by Machine Learning Applied to Virtual 4D-STEM Images
# 作者: DG Stroppa, R dos Reis
# 年份: 2024
# 期刊/會議: NA
# 摘要: 193 days ago -  machine-learning (ML) optimization approaches. Reference samples from  semiconductor devices  as a foundational comparison point for our machine learning (ML)-aided
# 引用次數: 0
# 文章連結: https://academic.oup.com/mam/article-pdf/doi/10.1093/mam/ozae044.120/58635055/ozae044.120.pdf
# PDF 連結: https://www.bio-conferences.org/articles/bioconf/pdf/2024/48/bioconf_emc2024_10013.pdf
# 引用文獻連結: None
# PDF 連結存在，但無法成功下載。
#
# === 第 63 筆結果 ===
# 標題: Authentication through residual attention-based processing of tampered optical responses
# 作者: B Wilson, Y Chen, D Kumar Singh, R Ojha
# 年份: 2024
# 期刊/會議: Advanced …
# 摘要: 200 days ago -  detection method for semiconductor devices that is robust under  devices,  generative machine learning model application exploration, and photonic/quantum devices
# 引用次數: 2
# 文章連結: https://www.spiedigitallibrary.org/journals/advanced-photonics/volume-6/issue-5/056002/Authentication-through-residual-attention-based-processing-of-tampered-optical-responses/10.1117/1.AP.6.5.056002.short
# PDF 連結: https://www.spiedigitallibrary.org/journals/advanced-photonics/volume-6/issue-05/056002/Authentication-through-residual-attention-based-processing-of-tampered-optical-responses/10.1117/1.AP.6.5.056002.full
# 引用文獻連結: /scholar?cites=9777549502390207899&as_sdt=5,33&sciodt=0,33&hl=en
# PDF 連結存在，但無法成功下載。
#
# === 第 64 筆結果 ===
# 標題: Revolutionizing Microwave Circuit Design with Machine Learning: Challenges and Opportunities
# 作者: J Ma, L Qiao, G Watkins, S Dang
# 年份: 2024
# 期刊/會議: IEEE …
# 摘要: 201 days ago -  Developing a direct ML model for inverse design tasks can be regarded as  training a reinforcement learning (RL) agent, which learns through trial and error to understand
# 引用次數: 1
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10634057/
# PDF 連結: https://research-information.bris.ac.uk/files/408023569/Final_Machine_Learning_Aided_Microwave_Circuit_Design_Challenges_and_Prospects.pdf
# 引用文獻連結: /scholar?cites=2879050258821535498&as_sdt=5,33&sciodt=0,33&hl=en
# PDF 連結存在，但無法成功下載。
#
# === 第 65 筆結果 ===
# 標題: Exploring machine learning for semiconductor process optimization: a systematic review
# 作者: YL Chen, S Sacchi, B Dey, V Blanco
# 年份: 2024
# 期刊/會議: … Artificial Intelligence
# 摘要: 201 days ago -  Deep Neural Network model and transfer learning model (which had  experience for millions of image classification) to solve alginment mark classification.
# 引用次數: 1
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10601235/
# PDF 連結: https://www.techrxiv.org/doi/pdf/10.36227/techrxiv.172114788.85190557
# 引用文獻連結: /scholar?cites=11758656075465231850&as_sdt=5,33&sciodt=0,33&hl=en
# PDF 連結存在，但無法成功下載。
#
# === 第 66 筆結果 ===
# 標題: Simulation and Characterization of Energetic Disorder and Recombination in Organic Solar Cells
# 作者: P Hartnagel
# 年份: 2024
# 期刊/會議: NA
# 摘要: 202 days ago -  This work thereby sets an example, how machine learning can facilitate highly   systems and then present the specific organic semiconductors used in this work and explain
# 引用次數: 0
# 文章連結: https://search.proquest.com/openview/fce6cbc21ec243dfd722a86345ae01e9/1?pq-origsite=gscholar&cbl=2026366&diss=y
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 67 筆結果 ===
# 標題: Improved Yield Prediction and Failure Analysis in Semiconductor Manufacturing with XGBoost and Shapley Additive exPlanations Models
# 作者: S Wang, Y Chen
# 年份: 2024
# 期刊/會議: 2024 IEEE International Symposium on the …
# 摘要: 203 days ago -  To address these issues, this study introduces an advanced machine learning  (ML)  role of artificial intelligence (AI) in enhancing semiconductor manufacturing processes.
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10691196/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 68 筆結果 ===
# 標題: The Applications of Simulation and Artificial Intelligence in Advanced Packaging
# 作者: Y Li, WP Kim
# 年份: 2024
# 期刊/會議: 2024 IEEE International Symposium on the …
# 摘要: 203 days ago -  into a format that can be understood by machine learning models, is the  key for a  data for generic failure modes in semiconductor devices, and how to develop AI
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10690932/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 69 筆結果 ===
# 標題: Addressing Class Imbalance and Data Limitations in Advanced Node Semiconductor Defect Inspection: A Generative Approach for SEM Images
# 作者: B Dey, V De Ridder, V Blanco, S Halder
# 年份: 2024
# 期刊/會議: 2024 International …
# 摘要: 204 days ago -  The escalating complexity of semiconductor devices  the robust training of  machine learning models. Addressing these  of machine learning models in semiconductor
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10694600/
# PDF 連結: https://arxiv.org/pdf/2407.10348
# 引用文獻連結: None
# 下載失敗: HTTPSConnectionPool(host='arxiv.org', port=443): Read timed out.
# PDF 連結存在，但無法成功下載。
#
# === 第 70 筆結果 ===
# 標題: Leveraging VGG16 deep learning for photovoltaic panel fault classification
# 作者: G Kaur, N Sharma, S Malhotra
# 年份: 2024
# 期刊/會議: 2024 2nd World …
# 摘要: 206 days ago -  They looked at a number of machine learning methods, such as class trees,  random  deep learning network can be used effectively to solve problems with semiconductors,
# 引用次數: 1
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10692258/
# PDF 連結: None
# 引用文獻連結: /scholar?cites=9986817880646204983&as_sdt=5,33&sciodt=0,33&hl=en
# 查無 PDF 連結或無法下載。
#
# === 第 71 筆結果 ===
# 標題: Demystifying Defects: Federated Learning and Explainable AI for Semiconductor Fault Detection
# 作者: T Patel, R Murugan, G Yenduri, R Jhaveri
# 年份: 2024
# 期刊/會議: IEEE …
# 摘要: 210 days ago -  the overall quality of semiconductor devices, reducing the  -driven methods  using machine learning methods are  data and pretrained deep neural networks (DNNs). The
# 引用次數: 1
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10589388/
# PDF 連結: https://ieeexplore.ieee.org/iel8/6287639/6514899/10589388.pdf
# 引用文獻連結: /scholar?cites=4469258952328926522&as_sdt=5,33&sciodt=0,33&hl=en
# PDF 連結存在，但無法成功下載。
#
# === 第 72 筆結果 ===
# 標題: Machine learning hardware accelerator for single-event-latchup (SEL) and micro-SEL detection in commercial-off-the-shelf (COTS) systems
# 作者: C Liao
# 年份: 2024
# 期刊/會議: NA
# 摘要: 213 days ago -  is catastrophic to semiconductor devices when it occurs.  device reliability and  lifespan. This dissertation involves a machine-learning-based (ML-based) and deep-learning
# 引用次數: 0
# 文章連結: https://dr.ntu.edu.sg/handle/10356/178793
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 73 筆結果 ===
# 標題: Effective Application-level Error Modeling of Permanent Faults on AI Accelerators
# 作者: F Pessia, JD Guerrero-Balaguera
# 年份: 2024
# 期刊/會議: 2024 IEEE 30th …
# 摘要: 215 days ago -  However, reliability concerns arise in devices with cutting-edge semiconductor   Deep Neural Networks (DNNs) are widely extended and highly effective Machine Learning (
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10616087/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 74 筆結果 ===
# 標題: Transmittance-Based Classification of Semiconductor Slit Designs: A Novel Multi-Layer Perceptron Approach
# 作者: S Sim, J Seo, N Yun, J Seok
# 年份: 2024
# 期刊/會議: 2024 Fifteenth International …
# 摘要: 216 days ago -  We also present the ratio of random and simple slit design data for optimal  learning  for machine learning model training, with implications for optimizing semiconductor
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10625268/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 75 筆結果 ===
# 標題: 시계열 AI 기반 진공펌프 이상 감지 개선
# 作者: 이혜영， 강민규， 정호영
# 年份: 2024
# 期刊/會議: 한국유체기계학회 학술대회 논문집
# 摘要: 218 days ago -  Dry vacuum pumps, as essential components of semiconductor processing  equipment, play a critical role in this context. Currently, dry vacuum pumps used in industrial
# 引用次數: 0
# 文章連結: https://www.dbpia.co.kr/Journal/articleDetail?nodeId=NODE11935219
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 76 筆結果 ===
# 標題: A Machine Learning-Based Method for Assisted Analysis and Decision Making of Wafer Yield
# 作者: J Qin
# 年份: 2024
# 期刊/會議: … 4th International Conference on Machine Learning …
# 摘要: 220 days ago -  neural networks (CNNs), a neural network specifically designed to process  image data, is a deep neural network  in semiconductor manufacturing[J]. IEEE Transactions on
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10674377/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 77 筆結果 ===
# 標題: The future of lab on a chip technologies: an early career scientists' perspective
# 作者: Y Fan, Z Li
# 年份: 2024
# 期刊/會議: Frontiers in Lab on a Chip Technologies
# 摘要: 224 days ago -  Unlike the widely accepted Moore’s Law in the semiconductor industry machine  learning in inertial microfluidics to promote the development process of microfluidic devices
# 引用次數: 0
# 文章連結: https://www.frontiersin.org/journals/lab-on-a-chip-technologies/articles/10.3389/frlct.2024.1449893/full
# PDF 連結: https://www.frontiersin.org/journals/lab-on-a-chip-technologies/articles/10.3389/frlct.2024.1449893/full
# 引用文獻連結: None
# PDF 連結存在，但無法成功下載。
#
# === 第 78 筆結果 ===
# 標題: Physics-Informed Multi-Task Learning for Material Removal Rate Prediction in Semiconductor Chemical Mechanical Planarization
# 作者: MW Rahman, GW Vogl, X Jia
# 年份: 2024
# 期刊/會議: 2024 IEEE International …
# 摘要: 231 days ago -  the asperities on the polishing pad, a machine learning-based  of physics-informed  machine learning for the MRR  Yan, “Multiloss regularized deep neural network,” IEEE
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10627679/
# PDF 連結: https://www.researchgate.net/profile/Md-Wahidur-Rahman-4/publication/383112951_Physics-Informed_Multi-Task_Learning_for_Material_Removal_Rate_Prediction_in_Semiconductor_Chemical_Mechanical_Planarization/links/670d7859b804975c1929d034/Physics-Informed-Multi-Task-Learning-for-Material-Removal-Rate-Prediction-in-Semiconductor-Chemical-Mechanical-Planarization.pdf
# 引用文獻連結: None
# PDF 連結存在，但無法成功下載。
#
# === 第 79 筆結果 ===
# 標題: Optimization of CdSeTe/CdTe Thin Film Photovoltaics Using Statistical Data and Machine Learning
# 作者: P Murugan, Z Lustig, A Munshi
# 年份: 2024
# 期刊/會議: 2024 IEEE 52nd Photovoltaic …
# 摘要: 239 days ago -  devices. Preliminary results using basic statistical methods have been used  and more inclusive models with machine learning  experimental fabrication of devices will be
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10748843/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 80 筆結果 ===
# 標題: Enhancing the Accuracy of Manufacturing Process Error Detection Through SMOTE-Based Oversampling Using Machine Learning and Deep Learning Techniques
# 作者: SV Boyapati, GBS Rakshitha
# 年份: 2024
# 期刊/會議: … on Integrated Circuits …
# 摘要: 240 days ago -  The development of semiconductors has significantly  Machine learning, data  mining, and deep learning offer a  This article suggests machine learning and deep learning
# 引用次數: 1
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10603197/
# PDF 連結: None
# 引用文獻連結: /scholar?cites=10928201076435098636&as_sdt=5,33&sciodt=0,33&hl=en
# 查無 PDF 連結或無法下載。
#
# === 第 81 筆結果 ===
# 標題: Integration of Artificial Neural Network Model for Smart Medical System Using Double Gate Mosfet
# 作者: EJ Leavline, V Krishnasamy
# 年份: 2024
# 期刊/會議: NA
# 摘要: 242 days ago -  machine learning technologies. The ANN was constructed by using double gate  MOSFET device.  created in analyzing medical images to work on semiconductor devices.
# 引用次數: 0
# 文章連結: https://www.researchsquare.com/article/rs-4196526/latest
# PDF 連結: https://www.researchsquare.com/article/rs-4196526/latest.pdf
# 引用文獻連結: None
# PDF 已下載至: pdf_files_Device\2024_Integration_of_Artificial_Neural_Network_Model_for_Smart_Medical_System_Using_Double_Gate_Mosfet.pdf_latest.pdf
#
# === 第 82 筆結果 ===
# 標題: Attention Assigning: Stacked Dual Network-Based Reinforcement Learning for Solving Assignment Problems
# 作者: H Shao, J Ge, G Wang
# 年份: 2024
# 期刊/會議: … and Artificial Intelligence (ICECAI)
# 摘要: 248 days ago -  When a shipment completes a certain process, it is very important to assign  which vehicle to transport the semiconductor or which machine to send to for the next process.
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10675000/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 83 筆結果 ===
# 標題: Large Language Model‐Based AI Agent for Organic Semiconductor Devices Research
# 作者: Q Zhang, Y Hu, J Yan, H Zhang, X Xie, J Zhu
# 年份: 2024
# 期刊/會議: Advanced …
# ...
# 引用次數: 1
# 文章連結: https://link.springer.com/content/pdf/10.1007/978-3-031-53092-0.pdf
# PDF 連結: https://www.researchgate.net/profile/Nathan-Gaw/publication/380658621_Introduction_to_Multimodal_and_Tensor_Data_Analytics/links/66d882d6b1606e24c2e19a53/Introduction-to-Multimodal-and-Tensor-Data-Analytics.pdf
# 引用文獻連結: /scholar?cites=111457757190816656&as_sdt=5,33&sciodt=0,33&hl=en
# PDF 連結存在，但無法成功下載。
#
# === 第 90 筆結果 ===
# 標題: Lithographic Hotspot Detection Using CNN
# 作者: SM Peter, KL Nisha, A Sankar
# 年份: 2024
# 期刊/會議: 2024 IEEE Recent Advances in …
# 摘要: 263 days ago -  semiconductor development. In this direction, an accurate HS detection method  is proposed using the convolutional neural networks  training the machine learning model.
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10690072/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 91 筆結果 ===
# 標題: Enhanced Prediction of Semiconductor Wafer Defects through CNN Forest Fusion and Random Methods for Improved Efficiency
# 作者: S Rawat, D Banerjee, A Gupta
# 年份: 2024
# 期刊/會議: … Conference on Advances …
# 摘要: 263 days ago -  The advancement of semiconductors has led to an  a machine learning  strategy for classifying apparent surface defects on semiconductor wafers using deep learning. In
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10582061/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 92 筆結果 ===
# 標題: Learning from Machine Learning: The case of band-gap directness in semiconductors
# 作者: GM Dalpian
# 年份: NA
# 期刊/會議: NA
# 摘要: 263 days ago -  Machine Learning methods to analyze a fundamental property of semiconductors  that lacks  We believe that these results demonstrate that explainable machine learning is
# 引用次數: 0
# 文章連結: https://phantomsfoundation.com/AI4AM/2024/Abstracts/AI4AM2024_Dalpian_Gustavo_14.pdf
# PDF 連結: https://phantomsfoundation.com/AI4AM/2024/Abstracts/AI4AM2024_Dalpian_Gustavo_14.pdf
# 引用文獻連結: None
# PDF 已下載至: pdf_files_Device\NA_Learning_from_Machine_Learning:_The_case_of_band-gap_directness_in_semiconductors.pdf_AI4AM2024_Dalpian_Gustavo_14.pdf
#
# === 第 93 筆結果 ===
# 標題: Toward Wireless System and Circuit Co-Design for the Internet of Self-Adaptive Things
# 作者: D Das, M Abdi, M Liu, M Onabajo
# 年份: 2024
# 期刊/會議: … on Dynamic Spectrum …
# 摘要: 266 days ago -  complementary metal-oxide semiconductor (CMOS) low-noise  and compensated  throughout the device lifetime [11].  about the integration of machine learning (ML) into
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10632802/
# PDF 連結: https://arxiv.org/pdf/2407.01808
# 引用文獻連結: None
# PDF 已下載至: pdf_files_Device\2024_Toward_Wireless_System_and_Circuit_Co-Design_for_the_Internet_of_Self-Adaptive_Things.pdf_2407.01808.pdf
#
# === 第 94 筆結果 ===
# 標題: Selective Auto-Labeling for Deep Learning-Based Domain-Specific Image Classification in Manufacturing
# 作者: J Park, W Ki, Y Lee, M Choi, JJ Park
# 年份: 2024
# 期刊/會議: … Semiconductor …
# 摘要: 266 days ago -  curated a dataset comprising images sourced from semiconductor equipment   , thereby driving forward the frontiers of machine learning and artificial intelligence.
# 引用次數: 1
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10545468/
# PDF 連結: None
# 引用文獻連結: /scholar?cites=1646164503725096173&as_sdt=5,33&sciodt=0,33&hl=en
# 查無 PDF 連結或無法下載。
#
# === 第 95 筆結果 ===
# 標題: Using BERT Pre-Trained Image Transformers to Identify Potential Parametric Wafer Map Defects
# 作者: E Jen, Y Ting, B Chen, CH Jan, L Huang
# 年份: 2024
# 期刊/會議: … Semiconductor …
# 摘要: 266 days ago -  [3] discusses a yield model based on machine learning for  This model  employs deep neural networks and  machine learning for yield prediction in semiconductor
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10545454/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 96 筆結果 ===
# 標題: An Implementation of a Machine Learning Methodology for Improving Test Data Quality
# 作者: HW HO, P Leenukiat
# 年份: 2024
# 期刊/會議: … Annual SEMI Advanced Semiconductor …
# 摘要: 266 days ago -  In deep learning models, there is convolution neural network (CNN) [1] which  is  Another model is the deep neural network (DNN) [2] (Fig. 1) mainly used for predicting an
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10545369/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 97 筆結果 ===
# 標題: Predictive Analysis and Root Cause Identification of Equipment Failures Using Event Log Patterns: A Focus on EUV/DUV Equipment
# 作者: W Ki, M Choi, Y Lee, J Park, JJ Park
# 年份: 2024
# 期刊/會議: … Semiconductor …
# 摘要: 266 days ago -  equipment, a critical component in the production of ultra-fine semiconductor  devices [ The integration of advanced machine learning techniques, such as Deep Learning
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10545492/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 98 筆結果 ===
# 標題: A survey of Reinforcement Learning for Electronic Design Automation
# 作者: H Zhu, X Chen
# 年份: 2024
# 期刊/會議: 2024 2nd International Symposium of …
# 摘要: 269 days ago -  The agent, which is a deep neural network, observes state from circuit then  selects  Placement in EDA strategically arranges electronic components on a semiconductor
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10617712/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 99 筆結果 ===
# 標題: Defect Pattern Classification of Wafer Graph based on Dual Channel Convolutional Neural Network
# 作者: F Lv, J Xie, W Li
# 年份: 2024
# 期刊/會議: 2024 6th International Conference on …
# 摘要: 269 days ago -  semiconductor manufacturing, we propose a lightweight method for nonhomologous  two-channel feature extraction method based on a convolutional neural network (CNN
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10653290/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 100 筆結果 ===
# 標題: SRP-PINN: A Physics-Informed Neural Network Model for Simulating Thermal Profile of Soldering Reflow Process
# 作者: A Farrag, J Kataoka, SW Yoon
# 年份: 2024
# 期刊/會議: IEEE Transactions on …
# 摘要: 270 days ago -  -based techniques or traditional machine learning (ML)  proposes a  Physics-Informed Neural Network (PINN),  the parameters of a deep neural network (DNN) using a
# 引用次數: 7
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10526426/
# PDF 連結: None
# 引用文獻連結: /scholar?cites=13813232904862229520&as_sdt=5,33&sciodt=0,33&hl=en
# 查無 PDF 連結或無法下載。
#
# === 第 101 筆結果 ===
# 標題: Neural network based deep learning analysis of semiconductor quantum dot qubits for automated control
# 作者: JR Taylor, SD Sarma
# 年份: 2024
# 期刊/會議: arXiv preprint arXiv:2405.04524
# 摘要: 271 days ago -  the devices in order to obtain meaningful and reproducible experimental results.  We propose that neural network based machine learning  enable a deep neural network to
# 引用次數: 2
# 文章連結: https://arxiv.org/abs/2405.04524
# PDF 連結: https://arxiv.org/pdf/2405.04524
# 引用文獻連結: /scholar?cites=4097609013877007139&as_sdt=5,33&sciodt=0,33&hl=en
# PDF 已下載至: pdf_files_Device\2024_Neural_network_based_deep_learning_analysis_of_semiconductor_quantum_dot_qubits_for_automated_control.pdf_2405.04524.pdf
#
# === 第 102 筆結果 ===
# 標題: Expressive Dendrites in Spiking Networks
# 作者: M Plagge, SG Cardwell
# 年份: 2024
# 期刊/會議: 2024 Neuro Inspired …
# 摘要: 286 days ago -  in a machine learning task with a SNN. Finally, we discuss potential deep learning   latency improvements compared to traditional deep neural networks, and as such much
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10548485/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 103 筆結果 ===
# 標題: Deep reinforcement learning framework for end-to-end semiconductor process control
# 作者: T Hirtz, H Tian, S Shahzad, F Wu, Y Yang
# 年份: 2024
# 期刊/會議: Neural Computing and …
# 摘要: 287 days ago -  This work focuses on bringing state-of-the-art artificial intelligence and deep  reinforcement learning to the manufacturing of semiconductor devices. The main goal of this
# 引用次數: 1
# 文章連結: https://link.springer.com/article/10.1007/s00521-024-09710-1
# PDF 連結: None
# 引用文獻連結: /scholar?cites=1225796441277367936&as_sdt=5,33&sciodt=0,33&hl=en
# 查無 PDF 連結或無法下載。
#
# === 第 104 筆結果 ===
# 標題: A Novel Image Deep Learning for Recognition of Silicon Photonics Redistribution Layer
# 作者: JK Fang, CK Hung, P Yang, WL Lu
# 年份: 2024
# 期刊/會議: 2024 IEEE 4th …
# 摘要: 290 days ago -  DL stems from machine learning (ML). Using neural networks as the basis for  DL  difference between traditional machine learning methods and novel deep learning lies in
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10602719/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 105 筆結果 ===
# 標題: High Speed Signal Design on Fan-Out RDL Interposer for Artificial Intelligence (AI) and Deep Neural Network (DNN) Chiplet Accelerators Application
# 作者: MH Zhuang, CY Shih, HC Lin, A Kang
# 年份: 2024
# 期刊/會議: 2024 International …
# 摘要: 292 days ago - Machine learning (ML) and artificial intelligence (AI) require more computing  capabilities that have access to large memory and storage. Heterogeneous chiplet
# 引用次數: 1
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10535433/
# PDF 連結: None
# 引用文獻連結: /scholar?cites=11176076481214131396&as_sdt=5,33&sciodt=0,33&hl=en
# 查無 PDF 連結或無法下載。
#
# === 第 106 筆結果 ===
# 標題: AI Model and Experimental Study of Drug Effects on Planarians' Regeneration
# 作者: E Li, Y Liu
# 年份: 2024
# 期刊/會議: … on Computing and Machine Intelligence (ICMI)
# 摘要: 296 days ago -  the first artificial intelligence machine-learning  machine learning models are  explored in this paper: a random forest classifier model, and a deep learning neural network
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10585905/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 107 筆結果 ===
# 標題: New techniques for assessing and enhancing the reliability of DNNs
# 作者: F Pessia
# 年份: 2024
# 期刊/會議: NA
# 摘要: 298 days ago -  Semiconductors manufacturers produce AI accelerators,  for NVDLA exploiting  Deep Neural Networks (DNNs)  Machine Learning is growing in popularity in our every
# 引用次數: 0
# 文章連結: https://webthesis.biblio.polito.it/31047/
# PDF 連結: https://webthesis.biblio.polito.it/secure/31047/1/tesi.pdf
# 引用文獻連結: None
# PDF 已下載至: pdf_files_Device\2024_New_techniques_for_assessing_and_enhancing_the_reliability_of_DNNs.pdf_tesi.pdf
#
# === 第 108 筆結果 ===
# 標題: Artificial intelligence measurement in imaging-based overlay metrology for performance boost
# 作者: S Grechin, S Katz, K Maeda, T Hirasawa
# 年份: 2024
# 期刊/會議: Metrology …
# 摘要: 300 days ago -  Advanced semiconductor devices target sub-2nm on- This work presents an  innovative Artificial Intelligence (AI)  image features and a deep learning model. The algorithm
# 引用次數: 0
# 文章連結: https://www.spiedigitallibrary.org/conference-proceedings-of-spie/12955/129552P/Artificial-intelligence-measurement-in-imaging-based-overlay-metrology-for-performance/10.1117/12.3010281.short
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 109 筆結果 ===
# 標題: An AI-Enabled Framework for Smart Semiconductor Manufacturing
# 作者: KSS Alamin, D Appello, A Beghi
# 年份: 2024
# 期刊/會議: … , Automation & Test …
# 摘要: 315 days ago -  Young, “Reinforcement learning for efficient scheduling in complex semiconductor  equipment,” in SEMI  Park, “A reinforcement learning approach to robust scheduling of
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10546768/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 110 筆結果 ===
# 標題: Reconfigurable photonic neuron
# 作者: B Garbin, LM Massaro, A Bazin
# 年份: 2024
# 期刊/會議: … Optics: Devices …
# 摘要: 326 days ago -  Mainstream Machine learning (ML) leverages on a simplified  Semiconductor  lasers have shown a neuron-like  consider a photonic crystal based semiconductor laser,
# 引用次數: 1
# 文章連結: https://www.spiedigitallibrary.org/conference-proceedings-of-spie/PC12889/PC128890H/Reconfigurable-photonic-neuron/10.1117/12.3012122.short
# PDF 連結: None
# 引用文獻連結: /scholar?cites=1115553253281788707&as_sdt=5,33&sciodt=0,33&hl=en
# 查無 PDF 連結或無法下載。
#
# === 第 111 筆結果 ===
# 標題: A Survey Based on FinFET Breaking the Moore's Law Barrier with Future Wireless Communication System
# 作者: S Karthik, R Tamilarasi
# 年份: 2024
# 期刊/會議: … Analysis and Deep Learning  …
# 摘要: 327 days ago -  of semiconductor device  machine learning and artificial neural networks. The  algorithm uses a combination of physical models, numerical methods, and machine learning
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10601380/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 112 筆結果 ===
# 標題: Stereo Vision Meta-Lens-Assisted Driving Vision
# 作者: X Liu, W Li, T Yamaguchi, Z Geng, T Tanaka
# 年份: 2024
# 期刊/會議: ACS …
# 摘要: 331 days ago -  meta-lens, and a complementary metal oxide semiconductor (CMOS) sensor.  In  -validation optimization mechanism and three deep learning modules for object detection,
# 引用次數: 18
# 文章連結: https://pubs.acs.org/doi/abs/10.1021/acsphotonics.3c01594
# PDF 連結: None
# 引用文獻連結: /scholar?cites=12646813349434134772&as_sdt=5,33&sciodt=0,33&hl=en
# 查無 PDF 連結或無法下載。
#
# === 第 113 筆結果 ===
# 標題: Hardware implementation of memristor-based artificial neural networks
# 作者: F Aguirre, A Sebastian, M Le Gallo, W Song
# 年份: 2024
# 期刊/會議: Nature …
# 摘要: 335 days ago -  Memristors, a novel beyond-complementary metal-oxide-semiconductor (CMOS)   device or a chip, it is essential to evaluate the accuracy of standard deep neural network
# 引用次數: 107
# 文章連結: https://www.nature.com/articles/s41467-024-45670-9
# PDF 連結: https://www.nature.com/articles/s41467-024-45670-9
# 引用文獻連結: /scholar?cites=5206836656225423304&as_sdt=5,33&sciodt=0,33&hl=en
# PDF 連結存在，但無法成功下載。
#
# === 第 114 筆結果 ===
# 標題: AI driven Process Diagnostic & Control: Device Manufacturing
# 作者: J Park
# 年份: 2024
# 期刊/會議: 2024 8th IEEE Electron Devices Technology & …
# 摘要: 337 days ago -  semiconductor industry is an intricate tapestry of technological advancements,  with machine learning (ML) at  Virtual metrology, utilizing Deep Neural Networks (DNN), has
# 引用次數: 2
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10511639/
# PDF 連結: None
# 引用文獻連結: /scholar?cites=18376033984090386735&as_sdt=5,33&sciodt=0,33&hl=en
# 查無 PDF 連結或無法下載。
#
# === 第 115 筆結果 ===
# 標題: Breath analysis system with convolutional neural network (CNN) for early detection of lung cancer
# 作者: B Lee, J Lee, JO Lee, Y Hwang, HK Bahn, I Park
# 年份: 2024
# 期刊/會議: Sensors and Actuators B …
# 摘要: 338 days ago -  and machine learning algorithms  deep learning algorithm. The breath analysis  system was designed to detect multiple VOCs in exhaled breath using ten semiconductor
# 引用次數: 18
# 文章連結: https://www.sciencedirect.com/science/article/pii/S0925400524003071
# PDF 連結: None
# 引用文獻連結: /scholar?cites=9239598193367814308&as_sdt=5,33&sciodt=0,33&hl=en
# 查無 PDF 連結或無法下載。
#
# === 第 116 筆結果 ===
# 標題: Pioneering Excellence in Semiconductor Manufacturing via XGBoost with BAT Optimization for Cutting-Edge Predictive Maintenance
# 作者: A Dwivedi, NR Khan
# 年份: 2024
# 期刊/會議: … on Big Data & Machine Learning  …
# 摘要: 345 days ago -  semiconductor manufacturing. These studies have utilized machine learning  (ML) and deep learning  notable contribution by utilizing machine learning models for process
# 引用次數: 0
# 文章連結: https://ieeexplore.ieee.org/abstract/document/10577393/
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
#
# === 第 117 筆結果 ===
# 標題: Pruning Quantized Unsupervised Meta-Learning DegradingNet Solution for Industrial Equipment and Semiconductor Process Anomaly Detection and Prediction
# 作者: YC Yu, SR Yang, SW Chuang, JT Chien, CY Lee
# 年份: 2024
# 期刊/會議: Applied Sciences
# 摘要: 348 days ago -  Machine learning for predictive diagnostics at the edge: An IIoT practical  example. In Proceedings of the ICC 2020–2020 IEEE International Conference on
# 引用次數: 2
# 文章連結: https://www.mdpi.com/2076-3417/14/5/1708
# PDF 連結: https://www.mdpi.com/2076-3417/14/5/1708
# 引用文獻連結: /scholar?cites=975050158736311222&as_sdt=5,33&sciodt=0,33&hl=en
# PDF 連結存在，但無法成功下載。
#
# === 第 118 筆結果 ===
# 標題: The Digitisation of the Sputter Deposition Process of Transparent Conductive Oxides by Implementing Artificial Intelligence
# 作者: M Hasnath
# 年份: 2024
# 期刊/會議: NA
# 摘要: 354 days ago -  of semiconducting material used for a wide variety application from flat panel  display to energy harvesting devices.  Machine Learning/Deep learning models were
# 引用次數: 0
# 文章連結: https://openresearch.lsbu.ac.uk/item/96532
# PDF 連結: None
# 引用文獻連結: None
# 查無 PDF 連結或無法下載。
